# %% [markdown]
# # Assignment: Square a Number
# This notebook helps you test your code before submitting.

# %%
# Clone your repository into Colabrepo_url = "https://github.com/CHRIST-SDS/test.git"!git clone $repo_url%cd test

# %%
# Run tests locally in Colab!pip install pytest!pytest -q
