# %% [markdown]
# # Assignment: Square a Number
# This notebook helps you test your code before submitting.
# Students: just run all cells. Tests will run automatically.

# %%
# 1️⃣ Download student code from GitHub Classroom repo
# Replace <STUDENT_USERNAME> and <STUDENT_REPO> with your repo info
# !mkdir -p student_code
# !wget -O student_code/main.py https://raw.githubusercontent.com/<STUDENT_USERNAME>/<STUDENT_REPO>/main/student_code/main.py

# %%
# 2️⃣ Add student_code folder to Python path
import sys
sys.path.insert(0, '/content/student_code')

# %%
# 3️⃣ Import student function
from main import square

# %%
# 4️⃣ Run pre-written tests
def run_tests():
    try:
        assert square(2) == 4, "Test 1 failed: square(2) != 4"
        assert square(-3) == 9, "Test 2 failed: square(-3) != 9"
        assert square(0) == 0, "Test 3 failed: square(0) != 0"
        print("All tests passed! ✅")
    except AssertionError as e:
        print(e)

run_tests()
